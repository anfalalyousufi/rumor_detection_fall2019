# %% [markdown]
# ### Overview of milestone 1
#
# ##### There are 3 main Research questions which will be answering in this project
#
# ###### Research Question 1: Predict whether a given tweet is a rumor or not. Research Question 2: Predict user demographic information of those who are spreading rumors. Research Question 3: Predict the topic/industry of rumors.
#
# ###### In order to understand about rumour prediction we have conducted an extensive literature review analysing previous work in this area. This folder consists report talking about the data collection and data cleaning and code for colleting data.

# %%
import tweepy
from tweepy import OAuthHandler
import pandas as pd
import matplotlib.pyplot as plt

pd.options.display.max_columns = 50
pd.options.display.max_rows= 50
pd.options.display.width= 120
 
consumer_key = 'RmYMHj3RwVL2qj2sB9V0jbGB2'
consumer_secret = 'rwkLatJck2pvHEeljerwWfwYi6Wf0Tquy90UyERunzFeXCAlW7'
access_token = '590766984-MJRgfipJLzhQt2R6VcktfsANXtiH6Rs87MUpl6ly'
access_secret = 'P6hl0Lwfclbcz4JjAWb9ILrTkyrPGB6cpd0UVGKmgGcZU'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
# Extract 2000 tweets based on the keyword
results = []
i=0
api = tweepy.API(auth, wait_on_rate_limit=True)
for tweet in tweepy.Cursor(api.search, q='@tesla', lang="en").items():
    results.append(tweet)
    id = tweet.id
    i=i+1
    if i==2000:
        break
        
print (len(results))
# Out:
# 2000

# %%
# Store the tweets in a dataframe
def process_results(results):
    id_list = [tweet.id for tweet in results]
    data_set = pd.DataFrame(id_list, columns=["id"])

    # Processing Tweet Data

    data_set["text"] = [tweet.text for tweet in results]
    data_set["created_at"] = [tweet.created_at for tweet in results]
    data_set["retweet_count"] = [tweet.retweet_count for tweet in results]
    data_set["favorite_count"] = [tweet.favorite_count for tweet in results]
    data_set["source"] = [tweet.source for tweet in results]

    # Processing User Data
    data_set["user_id"] = [tweet.author.id for tweet in results]
    data_set["user_screen_name"] = [tweet.author.screen_name for tweet in results]
    data_set["user_name"] = [tweet.author.name for tweet in results]
    data_set["user_created_at"] = [tweet.author.created_at for tweet in results]
    data_set["user_description"] = [tweet.author.description for tweet in results]
    data_set["user_followers_count"] = [tweet.author.followers_count for tweet in results]
    data_set["user_friends_count"] = [tweet.author.friends_count for tweet in results]
    data_set["user_location"] = [tweet.author.location for tweet in results]

    return data_set
data_set = process_results(results)

# %%
# Save the dataframe in a csv
data_set.to_csv("tesla.csv", index=False, encoding='utf-8')

# Repeat the process for all tweets

# %%
#df=pd.read_csv("FB1.csv")
df=pd.read_csv("tesla.csv")

# %%
df
# Out:
#                        id                                               text           created_at  retweet_count  \
# 0     1198348025317298176  RT @Tesla: I'm gonna tell my kids this is the ...  2019-11-23 21:10:08            675
# 1     1198348023027392512  @Tesla I’m in love with #Cybertruck. Congratul...  2019-11-23 21:10:07              0
# 2     1198348009525989377  RT @Tesla: I'm gonna tell my kids this is the ...  2019-11-23 21:10:04            675
# 3     1198348000407543808  RT @Tesla: I'm gonna tell my kids this is the ...  2019-11-23 21:10:02            675
# 4     1198347990513209345  RT @Tesla: I'm gonna tell my kids this is the ...  2019-11-23 21:09:59            675
# 5     1198347987975577601  @denverbitcoin @Tesla I'm thinking it was very...  2019-11-23 21:09:59              0
# 6     1198347986985553920  RT @Tesla: I'm gonna tell my kids this is the ...  2019-11-23 21:09:58            675
# 7     1198347984242528256  RT @Tesla: I'm gonna tell my kids this is the ...  2019-11-23 21:09:58            675
# 8     1198347980199415808  RT @Tesla: I'm gonna tell my kids this is the ...  2019-11-23 21:09:57            675
# 9     1198347975384322048  RT @Tesla: I'm gonna tell my kids this is the ...  2019-11-23 21
# 1991  1198332219619606528  Dammit @Tesla and @elonmusk I can’t stop think...  2019-11-23 20:07:19              0
# 1992  1198332212988366848  @dylanlockemp3 @Casey @Tesla I need this in my...  2019-11-23 20:07:18              0
# 1993  1198332206676152321  @LikeTeslaKim @Tesla The apparent lack of ener...  2019-11-23 20:07:16              0
# 1994  1198332195880022019  @BTCarchitect @Tesla @elonmusk The cybertruck ...  2019-11-23 20:07:14              0
# 1995  1198332187407503366  RT @DrSepah: @adamnash @Tesla Agreed https://t...  2019-11-23 20:07:12              1
# 1996  1198332178310082561  @BlessRNG @Tesla Show me your pre-order @BlessRNG  2019-11-23 20:07:09              0
# 1997  1198332170869366785  @altontowers But will you get your act togethe...  2019-11-23 20:07:08              0
# 1998  1198332166586994694       @Casey @Tesla Keeping up with the Joneses. 🙄  2019-11-23 20:07:07              0
# 1999  1198332164875718657  RT @DigitalTrends: This bed was made for sleep...  2019-11-23 20:07:06              9
#
#       favorite_count               source              user_id user_screen_name                         user_name  \
# 0                  0     Tweetbot for Mac  1168156235297779713     teslatactics                     Tesla Tactics
# 1                  0     Twitter for iPad   869205893921034240   russian_bedbug                    🇺🇸 Patriot Dog
# 2                  0  Twitter for Android            241400860     enerphyschem                    Complex - Mich
# 3                  0   Twitter for iPhone            491028177      thisisjboi9                       Johnny Rico
# 4                  0  Twitter for Android  1052533155146723328      MunckSergio                      Sérgio Munck
# 5                  0      Twitter Web App            293883644         tuns1999                      Brad Johnson
# 6                  0   Twitter for iPhone   828670675199987712  saucemasterjazz                  wholelottabread🍞
# 7                  0   Twitter for iPhone           1571707580       muribejr85                      Manuel Uribe
# 8                  0   Twitter for iPhone            733735932       ggiancolaa                          Giancola
# 9                  0   Twitter for iPhone           4820372663  donovan_saenger                   Donovan Saenger
# 10                 0   Twitter for iPhone   771097114361237504    davidmhadley1                      David Hadley
# 11                 0   Twitter for iPhone            197509165  ButterHoneyMilk                   ButterMilkHoney
# 12                 0  Twitter for Android  1193162055219601408        H3ndriksJ                        J.H3ndriks
# 13                 0   Twitter for iPhone           2941432864         Hubson__                 GEOFFREY I.M. 🤮 💶
# 14                 0   Twitter Web Client   751232777400492032    DaleDiswaneck                        Diana Dale
# 15                 0   Twitter for iPhone            349808082       kota_baird                      𝚔𝚘𝚝𝚊𝚋𝚊𝚒𝚛𝚍 ✞✞
# 16                 0  Twitter for Android            839219437   NiambhScullion                 Niambh Girly-Swot
# 17                 0      Twitter Web App  1068486886077988864  CryptoLoveChris                   Crypto Chris 💙🎄
# 18                 1  Twitter for Android           2307884225  HerveManiraguha                          Hervé M.
# 19                 0   Twitter for iPhone   885966567099564034      SuperFERMOR                     SuperFERMOR ❼
# 20                 0   Twitter for iPhone  1147885295863513089           jch008                             James
# 21                 0  Twitter for Android   842814927379333120   SciTechMachINe                     Common - Mich
# 22                 0   Twitter for iPhone            779110058    JosephOrtiz__                        Uncle Joey
# 23                 0   Twitter for iPhone           1662940338         _KingA18                             King™
# 24                 0      Twitter Web App           3260215053       NickFirzen                       Nick Firzen
# ...              ...                  ...                  ...              ...                               ...
# 1975               2   Twitter for iPhone   985686123123949568    Kristennetten                             K10 ✨
# 1976               0   Twitter for iPhone           3050740823        FrkEngvej                      Karen Hansen
# 1977               1            TweetDeck             56151063         BlessRNG  BlessRNG🙏 | Brad Jolly @ Home?!?
# 1978               0   Twitter for iPhone           1460621474     mrsimongreen                       Simon Green
# 1979               0   Twitter for iPhone             12736282       gopisangha     🔊☀️🐅 Tiger Balm Gopi ♨️👳🏾‍♂️📲
# 1980               0      Twitter Web App  1189754861249650689      DMustelidae                  Diane Mustelidae
# 1981               5  Twitter for Android  1053698178040635392            ASJCS                              ASJC
# 1982               0   Twitter for iPhone           2939099302      VikDimitrov                   Viktor Dimitrow
# 1983               0   Twitter for iPhone           3193539620           Dmaz75                               MPD
# 1984               0   Twitter for iPhone            349411635            S1N3N                             S1N3N
# 1985               0  Twitter for Android           3059287647     BakasaMartin                     Bakasa Martin
# 1986               0   Twitter for iPhone            354768929       mdaleburns                          Mr.Burns
# 1987               0   Twitter for iPhone             24770474      BullMoose75                      M-A-DOUBLE T
# 1988               2      Twitter Web App   930171393660010497   SimonTurner_NZ                             Simon
# 1989              12   Twitter for iPhone           3699668774     CarolineGee8                      👻Caroline G.
# 1990               1      Twitter Web App           1360097478       aaronglz23                   𝔸𝕒𝕣ó𝕟 𝕊𝕥𝕒𝕣𝕜 Ⓥ 🎄
# 1991               0   Twitter for iPhone   902977106367229952    PeterLindbeck                    Peter Lindbeck
# 1992               0   Twitter for iPhone           4856038759  MaverickGamer97                          Maverick
# 1993               0      Twitter Web App             17239694          mecredy                               ron
# 1994               0  Twitter for Android   945240613091467264       daolexicon  headieddie (non-giver of MORTY$)
# 1995               0   Twitter for iPhone             76963073     paulhayesman                        paul hayes
# 1996               0   Twitter for iPhone            349411635            S1N3N                             S1N3N
# 1997               1   Twitter for iPhone   884070714269106176         OtterIan                       Ian Otter 👻
# 1998               0   Twitter for iPhone             22675346           SlyDvl                             C𝓲𝓼𝓬𝓸
# 1999               0      Twitter Web App           1004747094      Sir_Johnjee                           O. John
#
#           user_created_at                                   user_description  user_followers_count  \
# 0     2019-09-01 13:38:53  Tesla shenanigans on youtube!\nhttps://t.co/l0...                    12
# 1     2017-05-29 14:56:48  One of many, like no other. I like crayons, ch...                    95
# 2     2011-01-22 04:53:37                       Tech-Science..Complex Things                   243
# 3     2012-02-13 05:21:58                   I have to return some videotapes                   789
# 4     2018-10-17 12:13:54  😎 Aqui e Galo @atletico !!\nSeattle Seahawks! ...                   337
# 5     2011-05-06 04:29:04  I am a Canadian, free to speak without fear, f...                  1522
# 6     2017-02-06 18:24:19           🍊C Butter my butt and call me a biscuit.                   520
# 7     2013-07-06 01:20:01                                                NaN                    21
# 8     2012-08-02 23:24:20                                     Ig: ggiancolaa                   406
# 1997  2017-07-09 15:24:18  Amiga computer enthusiast. Totally obsessed wi...                   118
# 1998  2009-03-03 20:40:00                                                NaN                     6
# 1999  2012-12-11 19:50:00  Don't tell me the sky is the limit when there ...                   133
#
#       user_friends_count                           user_location
# 0                     54                                 Arizona
# 1                    380                   East Coast Elite City
# 2                    328                                      @?
# 3                    525                           Kalamazoo, MI
# 4                    697                  Belo Horizonte, Brasil
# 5                   1615                         Toronto, Canada
# 6                    969                                 714ever
# 7                    126                                     NaN
# 8                    353                                     NaN
# 9                    253                         London, England
# 10                    76                             Seattle, WA
# 11                    80                       San Francisco, CA
# 12                   109                         Space Coast, FL
# 13                    55                         Liège/Bruxelles
# 14                  9260                                     NaN
# 15                   990                                     NaN
# 16                  2438                    Dublin City, Ireland
# 17                  1891                                    Home
# 18                   243                          Genève, Suisse
# 19                   376                        Mushroom Kingdom
# 20                    60                                     NaN
# 21                   526                                      @?
# 22                   442                                      az
# 23                  1249                                     NaN
# 24                  2722                       Hungary, Budapest
# ...                  ...                                     ...
# 1975                2935                           Pacific ⬆️⬅️
# 1976                  69                       Sjælland, Danmark
# 1977                6581                Melbourne VIC, Australia
# 1978                  40                         Munich, Bavaria
# 1979                1078                         Los Angeles, CA
# 1980                 197                                     NaN
# 1981                 483                                    Mars
# 1982                 181                                Bulgaria
# 1983                 250                                     NaN
# 1984                1499                            The Internet
# 1985                 393                            New York, NY
# 1986                 103                           Colorado, USA
# 1987                1065  Wisconsin to Puget Sound to Portlandia
# 1988                 653                             New Zealand
# 1989                2068                Northern California, USA
# 1990                5002                   Canary Islands, Spain
# 1991                  87                          Sacramento, CA
# 1992                 227                                     NaN
# 1993                 279                       Washington, DCish
# 1994                1137                                     NaN
# 1995                6756                                  dublin
# 1996                1499                            The Internet
# 1997                 153                                     NaN
# 1998                  82                                     NaN
# 1999                1022                   Jericho Hill, Nigeria
#
# [2000 rows x 14 columns]

# %%
#df.columns = ['tweet', 'label']
#df

# %%
#Balanced Dataset

dfb_r = df[df['label'] == 1]     #rumors
dfb_nr = df[df['label'] == 0]    #Non-Rumors

dfb_nr = dfb_nr.sample(n=30965)  #sampling equal amount of Non-Rumors

dfb = dfb_r.append(dfb_nr)        #concatenating Rumors and Non-Rumors
dfb= dfb.sample(frac=1).reset_index(drop=True)   #Shuffling the dataset

# %%
dfb

# %%
def preprocess(text):
    
#     PreProcessing 
#     1. Lower
#     2. Removing Speciial Characters
#     3. Removing numbers
#     4. Removing Mentions
#     5. Removing Urls
#     6. Removing Stopwords
#     7. Removing all non-alphanumeric characters
#     8. Lemmatization
    
    
    lemmatizer = WordNetLemmatizer()
    text = text.lower()
    
    emoji_pattern = re.compile("["
            u"\U0001F600-\U0001F64F"  # emoticons
            u"\U0001F300-\U0001F5FF"  # symbols & pictographs
            u"\U0001F680-\U0001F6FF"  # transport & map symbols
            u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                            "]+", flags=re.UNICODE)
        
    text = emoji_pattern.sub(r'',text)                          #removes emojis and other symbols 
    text = re.sub('[,.?~!$%&*#/]','',text)                      #special Characters
    text = re.sub('[\d]','',text)                               #removes numbers
    words = [word for word in text.split() if '@' not in word]  #removes mentions
    words = [word for word in words if 'https:' not in word or 'http:' not in word]  #removes urls
    words = [word for word in words if word not in stopwords.words('english')]       #removes stopwords
    words = [word for word in words if  not re.search('\W+',word)]                   #removes non-alphanumerics chars
    words = [lemmatizer.lemmatize(word) for word in words ]                          #Lemmatization
    text = ' '.join(words)
    
    return text
    
text = "hello this i$ some# @sting /// â€˜banksyâ€™  \U0001F600   with some .,m.m *& daf8 random things in it."
print(preprocess(text))

# %%
## Unbalanced Dataset
#df_new['tweet'].apply(preprocess)

#Preprocessing Balanced Dataset
dfb['tweet'] = dfb['tweet'].apply(preprocess)

# %%
dfb.columns = ['tweet', 'label']
dfb

# %%
from sklearn.model_selection import train_test_split

# x = df_new['tweet']
# y = df_new['label']

x = dfb['tweet']
y = dfb['label']

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.20, random_state = 42)

# %%
x_train

# %%
import numpy as np
import json
import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences



vocab_size = 1000
embedding_dim = 50
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size = 20000
GLOVE_DIR = "D:\\MyProject\\glove.twitter.27B"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(x_train)

word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(x_train)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(x_test)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)






#Unpacking Glove Embedding
embeddings_index = {}
f = open(os.path.join(GLOVE_DIR, 'glove.twitter.27B.50d.txt'), encoding = 'utf-8')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Found %s word vectors.' % len(embeddings_index))

#Creating Glove Embedding Matrix
embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %%
#model 1: Embeddings
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(len(word_index) + 1, embedding_dim, weights=[embedding_matrix], input_length=max_length, trainable = False),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences = True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid') ])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()


#model 2: Embeddings with Conv1D and maxpooling1D
# model = tf.keras.Sequential([
#     tf.keras.layers.Embedding(len(word_index) + 1, embedding_dim, weights=[embedding_matrix], input_length=max_length, trainable = False),
#     tf.keras.layers.Conv1D(64,4,activation = 'relu'),
#     tf.keras.layers.Dropout(0.3),
#     tf.keras.layers.MaxPooling1D(2),
#     tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences = True)),
#     tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)),
#     tf.keras.layers.Dense(128, activation='relu'),
#     tf.keras.layers.Dense(1, activation='sigmoid') ])
# model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# model.summary()







num_epochs = 20
history = model.fit(training_padded, y_train, epochs=num_epochs, validation_data=(testing_padded, y_test),batch_size = 1024, verbose=1)

# %%
y_train_prediction = model.predict(training_padded)
y_test_prediction =    model.predict(testing_padded)
y_train_prediction[y_train_prediction >= 0.5] = 1
y_train_prediction[y_train_prediction <  0.5] = 0
y_test_prediction[y_test_prediction >= 0.5] = 1
y_test_prediction[y_test_prediction <  0.5] = 0

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
from sklearn import metrics
import numpy as np

print("Accuracy (training data)\n", metrics.accuracy_score(y_train, y_train_prediction))
print("Accuracy (test data)\n", metrics.accuracy_score(y_test, y_test_prediction))

print("Confusion matrix (training data)\n", metrics.classification_report(y_train, y_train_prediction))
print("Confusion matrix (test data)\n", metrics.classification_report(y_test, y_test_prediction))

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'acc')
plot_graphs(history, 'loss')

# %%
model.save("rumor_detection_word_embeddin_20iterations.h5")

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
